# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_excel(r'C:\Users\abhay\OneDrive\Desktop\data_science_project\online_retail_II.xlsx', sheet_name=0)

# %%
cleaned_df = df.copy()

# %%
# we will clean the invoice column in the dataset first

cleaned_df["Invoice"] = cleaned_df["Invoice"].astype("str")
mask = (
    cleaned_df["Invoice"].str.match("^\\d{6}$") == True
)

cleaned_df = cleaned_df[mask]

# %%
cleaned_df

# here we have cleared all rows of invoice that do not contain, 
# 6-digits in a row
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#                InvoiceDate  Price  Customer ID         Country
# ...

# %%
# now we will look at stock codes

cleaned_df["StockCode"] = cleaned_df["StockCode"].astype("str")
mask = (
    (cleaned_df["StockCode"].str.match("^\\d{5}$") == True) |
    (cleaned_df["StockCode"].str.match("^\\d{5}[a-zA-Z]+$") == True) |
    (cleaned_df["StockCode"].str.match("^PADS$") == True)
)

cleaned_df = cleaned_df[mask]

# %%
cleaned_df

# we have cleared all the unnesesary variants present in the stockcode, that we found 
# the exploratory analysis, except for pads, as we wanted to include them, and removed
# every other unneeded variant from the dataset
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#                InvoiceDate  Price  Customer ID         Country
# ...

# %%
cleaned_df.describe()
# Out:
#             Quantity                    InvoiceDate          Price  \
# count  512796.000000                         512796  512796.000000
# mean       11.001279  2010-06-28 18:26:52.709732352       3.391447
# min     -9600.000000            2009-12-01 07:45:00       0.000000
# 25%         1.000000            2010-03-21 13:27:00       1.250000
# 50%         3.000000            2010-07-06 14:25:00       2.100000
# 75%        10.000000            2010-10-15 14:50:00       4.210000
# max     19152.000000            2010-12-09 20:01:00    1157.150000
# std       104.352433                            NaN       5.067864
#
#          Customer ID
# count  406337.000000
# mean    15373.632992
# min     12346.000000
# 25%     14004.000000
# 50%     15326.000000
# 75%     16814.000000
# max     18287.000000
# std      1677.365907

# %%
# the above processes removed almost all the negative data from the dataset.
# but still in quantity we can find -ve values 
# and also drop the null customer IDS that are present in the dataset

# %%
cleaned_df.dropna(subset=["Customer ID"], inplace=True)
# Out:
# C:\Users\abhay\AppData\Local\Temp\ipykernel_3800\1633333693.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df.dropna(subset=["Customer ID"], inplace=True)

# %%
cleaned_df.describe()
# Out:
#             Quantity                    InvoiceDate          Price  \
# count  406337.000000                         406337  406337.000000
# mean       13.619099  2010-07-01 10:11:06.543288320       2.991462
# min         1.000000            2009-12-01 07:45:00       0.000000
# 25%         2.000000            2010-03-26 14:01:00       1.250000
# 50%         5.000000            2010-07-09 15:48:00       1.950000
# 75%        12.000000            2010-10-14 17:09:00       3.750000
# max     19152.000000            2010-12-09 20:01:00     295.000000
# std        97.000659                            NaN       4.285876
#
#          Customer ID
# count  406337.000000
# mean    15373.632992
# min     12346.000000
# 25%     14004.000000
# 50%     15326.000000
# 75%     16814.000000
# max     18287.000000
# std      1677.365907

# %%
# after dropping all the null custoer IDs from the dataset, we have now no -ve
# values present in the dataset 
# but still have '0' values present in the data which may be some free prod that cust
# has got, but we dont want them in the analysis so we will clean them

# %%
cleaned_df[cleaned_df["Price"] == 0]
# Out:
#        Invoice StockCode                        Description  Quantity  \
# 4674    489825     22076                 6 RIBBONS EMPIRE          12
# 6781    489998     48185                DOOR MAT FAIRY CAKE         2
# 18738   490961     22065     CHRISTMAS PUDDING TRINKET POT          1
# 18739   490961     22142       CHRISTMAS CRAFT WHITE FAIRY         12
# 32916   492079     85042          ANTIQUE LILY FAIRY LIGHTS         8
# 40101   492760     21143    ANTIQUE GLASS HEART DECORATION         12
# 47126   493761     79320                    FLAMINGO LIGHTS        24
# 48342   493899     22355        CHARLOTTE BAG , SUKI DESIGN        10
# 57619   494607     21533          RETRO SPOT LARGE MILK JUG        12
# 111348  500073     21662         VINTAGE GLASS COFFEE CADDY         1
# 149201  503585     22459       CAST IRON HOOK GARDEN TROWEL         8
# 149202  503585     22458         CAST IRON HOOK GARDEN FORK         8
# ...

# %%
len(cleaned_df[cleaned_df["Price"] == 0])

# there are very less values so let us filter them
# Out:
# 28

# %%
cleaned_df = cleaned_df[cleaned_df["Price"] > 0]

# %%
cleaned_df.describe()
# Out:
#             Quantity                    InvoiceDate          Price  \
# count  406309.000000                         406309  406309.000000
# mean       13.617924  2010-07-01 10:14:25.869572352       2.991668
# min         1.000000            2009-12-01 07:45:00       0.001000
# 25%         2.000000            2010-03-26 14:01:00       1.250000
# 50%         5.000000            2010-07-09 15:48:00       1.950000
# 75%        12.000000            2010-10-14 17:09:00       3.750000
# max     19152.000000            2010-12-09 20:01:00     295.000000
# std        96.998833                            NaN       4.285951
#
#          Customer ID
# count  406309.000000
# mean    15373.722268
# min     12346.000000
# 25%     14006.000000
# 50%     15326.000000
# 75%     16814.000000
# max     18287.000000
# std      1677.329470

# %%
# we still have a small valve 0.001000, which we can ignore as long as
# as there are no absolute 0 values

# %%
# let us check how much data we lost during the cleaning process, 
# this is important in industries and is also a good practise

# %%
len(cleaned_df)/len(df)
# Out:
# 0.7732429238325965

# %% [markdown]
# we still have "77%" of our data
# which means we have lost around "23%" of data in our cleaning process

# %%
clean_data = cleaned_df
clean_data.to_csv("cleaned_df.csv")
